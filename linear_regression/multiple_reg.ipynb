# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# C:\Users\rajem\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df=pd.read_csv('economic_index.csv')

# %%
df
# Out:
#     Unnamed: 0  year  month  interest_rate  unemployment_rate  index_price
# 0            0  2017     12           2.75                5.3         1464
# 1            1  2017     11           2.50                5.3         1394
# 2            2  2017     10           2.50                5.3         1357
# 3            3  2017      9           2.50                5.3         1293
# 4            4  2017      8           2.50                5.4         1256
# 5            5  2017      7           2.50                5.6         1254
# 6            6  2017      6           2.50                5.5         1234
# 7            7  2017      5           2.25                5.5         1195
# 8            8  2017      4           2.25                5.5         1159
# 9            9  2017      3           2.25                5.6         1167
# 10          10  2017      2           2.00                5.7         1130
# ...

# %%
# Fixed: Removed axis=1 and corrected the "Unnamed" typo
df.drop(columns=["Unnamed: 0", "year", "month"], inplace=True)

# %%
df
# Out:
#     interest_rate  unemployment_rate  index_price
# 0            2.75                5.3         1464
# 1            2.50                5.3         1394
# 2            2.50                5.3         1357
# 3            2.50                5.3         1293
# 4            2.50                5.4         1256
# 5            2.50                5.6         1254
# 6            2.50                5.5         1234
# 7            2.25                5.5         1195
# 8            2.25                5.5         1159
# 9            2.25                5.6         1167
# 10           2.00                5.7         1130
# 11           2.00                5.9         1075
# 12           2.00                6.0         1047
# 13           1.75                5.9          965
# 14           1.75                5.8          943
# 15           1.75                6.1          958
# 16           1.75                6.2          971
# 17           1.75                6.1          949
# ...

# %%
## check null values
df.isnull().sum()
# Out:
# interest_rate        0
# unemployment_rate    0
# index_price          0
# dtype: int64

# %%
## lets do visualization
import seaborn as sns
sns.pairplot(data=df)
plt.show()

# %%
df.corr()
# Out:
#                    interest_rate  unemployment_rate  index_price
# interest_rate           1.000000          -0.925814     0.935793
# unemployment_rate      -0.925814           1.000000    -0.922338
# index_price             0.935793          -0.922338     1.000000

# %%
## visualize the data points
plt.scatter(df['interest_rate'],df['unemployment_rate'],color="r")
plt.ylabel("unemployment_rate")
plt.xlabel("interest_rate")
plt.show()

# %%
## independent features and dependent features
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#     interest_rate  unemployment_rate
# 0            2.75                5.3
# 1            2.50                5.3
# 2            2.50                5.3
# 3            2.50                5.3
# 4            2.50                5.4
# 5            2.50                5.6
# 6            2.50                5.5
# 7            2.25                5.5
# 8            2.25                5.5
# 9            2.25                5.6
# 10           2.00                5.7
# 11           2.00                5.9
# 12           2.00                6.0
# 13           1.75                5.9
# 14           1.75                5.8
# 15           1.75                6.1
# 16           1.75                6.2
# 17           1.75                6.1
# 18           1.75                6.1
# 19           1.75                6.1
# 20           1.75                5.9
# 21           1.75                6.2
# 22           1.75                6.2
# 23           1.75                6.1

# %%
y
# Out:
# 0     1464
# 1     1394
# 2     1357
# 3     1293
# 4     1256
# 5     1254
# 6     1234
# 7     1195
# 8     1159
# 9     1167
# 10    1130
# 11    1075
# 12    1047
# 13     965
# 14     943
# 15     958
# 16     971
# 17     949
# 18     884
# 19     866
# 20     876
# 21     822
# 22     704
# 23     719
# Name: index_price, dtype: int64

# %%
## train test spliy
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
sns.regplot(x=df["interest_rate"],y=df["index_price"])
plt.show()

# %%
sns.regplot(x=df["unemployment_rate"],y=df["index_price"])
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
x_train=scalar.fit_transform(x_train)
x_test=scalar.transform(x_test)
# Out:
# C:\Users\rajem\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2684: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(

# %%
x_train
# Out:
# array([[-0.90115511,  0.37908503],
#        [ 1.31077107, -1.48187786],
#        [-0.90115511,  1.30956648],
#        [ 1.31077107, -0.55139641],
#        [ 1.31077107, -1.48187786],
#        [-0.16384638,  0.68924552],
#        [-0.90115511,  0.999406  ],
#        [ 1.31077107, -1.48187786],
#        [ 1.31077107, -1.17171738],
#        [-0.90115511,  1.30956648],
#        [-0.90115511,  0.999406  ],
#        [-0.90115511,  0.37908503],
#        [-0.90115511,  0.999406  ],
#        [ 0.57346234, -0.8615569 ],
#        [-0.16384638, -0.24123593],
#        [-0.90115511,  0.06892455],
#        [-0.90115511,  0.999406  ],
#        [ 1.31077107, -0.8615569 ]])

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# %config Completer.use_jedi = False

# %%
## this is used for the when we have multiple features in the dataset and need to fine tune the model

from sklearn.model_selection import cross_val_score
validation_score=cross_val_score(reg,x_train,y_train,scoring='neg_mean_squared_error',cv=3)

# %%
validation_score
# Out:
# array([-4921.61331265, -7686.87497294, -5135.9962549 ])

# %%
np.mean(validation_score)
# Out:
# np.float64(-5914.828180162389)

# %%
## prediction
y_pred=reg.predict(x_test)

# %%
y_pred
# Out:
# array([612.64375972, 487.12736973, 680.03156939, 498.75308579,
#        544.07270669, 601.01804366])

# %%
# !pip install "jedi<=0.18.2"
# Out:
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    -------------------- ------------------- 0.8/1.6 MB 1.9 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.6 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 1.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: jedi
#     Found existing installation: jedi 0.19.2
#     Uninstalling jedi-0.19.2:
#       Successfully uninstalled jedi-0.19.2
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\rajem\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\rajem\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\rajem\anaconda3\Lib\site-packages)

# %%
## performance metrics\
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)
print("rmse=",rmse)
print("mse=",mse)
print("mae=",mae)
# Out:
# rmse= 562.4172404909528
# mse= 316313.15240145824
# mae= 549.3922441707887
